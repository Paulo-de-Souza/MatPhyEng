# %% [markdown]
# # Capítulo 7 - Visualizacao

# %% [markdown]
# ## 7.1 - Plots e Basic Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

L = 10
x = np.linspace(-L, L, 100)
f = np.cos(x)
g = np.sin(0.2 * x**2) * np.exp(-0.02 * x**2)

plt.subplot(2, 1, 1)
plt.plot(x, f, 'm', label='f(x)')
plt.plot(x, g, 'k', label='g(x)')
plt.legend()
plt.title('$\\xi^2$ dependence', fontsize=12)

plt.subplot(2, 1, 2)
plt.plot(x, f, 'm', linewidth=6)
plt.plot(x, g, 'k', linewidth=2)
plt.xlim([-10, 10])
plt.xticks([-10, -7.5, -5, -2.5, 0, 2.5, 5, 7.5, 10],
           ['-L', '', '-5', '', '0', '', '5', '', 'L'])
plt.yticks([-1.5, -1, -0.5, 0, 0.5, 1.0, 1.5],
           ['', 'min', '', '0', '', 'max', ''])
plt.xlabel('space $\\xi$', fontsize=12)

# Annotation
plt.annotate('cos(x)', xy=(0.5, -0.05), xytext=(0.8, 0.1), textcoords='axes fraction',
             arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12)

plt.savefig('adv_plot1new.eps', format='eps', bbox_inches='tight')

plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Basico 2D

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Define parameters
L = 10
x = np.linspace(-L, L, 40)
y = x
X, Y = np.meshgrid(x, y)
m = 1  # number of spirals

# Calculate u
u = np.tanh(np.sqrt(X**2 + Y**2)) * np.cos(m * np.angle(X + 1j * Y) - np.sqrt(X**2 + Y**2))

fig = plt.figure()
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(221, projection='3d')
ax.plot_surface(X, Y, u, cmap='coolwarm')
plt.gca().set_xticks([])
plt.gca().set_yticks([])
plt.gca().set_zticks([])

ax = fig.add_subplot(222, projection='3d')
ax.plot_surface(X, Y, u, cmap='coolwarm')
ax.contour(X, Y, u, zdir='u', offset=np.min(u), cmap='coolwarm', linestyles='solid')
plt.gca().set_xticks([])
plt.gca().set_yticks([])
plt.gca().set_zticks([])

ax = fig.add_subplot(223, projection='3d')
ax.contourf(X, Y, u, cmap=cm.coolwarm)
plt.gca().set_xticks([])
plt.gca().set_yticks([])
plt.gca().set_zticks([])

ax = fig.add_subplot(224, projection='3d')
ax.plot_wireframe(X, Y, u, color='black', alpha=0.5)
plt.gca().set_xticks([])
plt.gca().set_yticks([])
plt.gca().set_zticks([])

plt.savefig('adv_plot2new.eps', format='eps', bbox_inches='tight')

plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure()
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(221)
ax.pcolor(x, y, u, edgecolors='k', linewidths=1, cmap='coolwarm')
ax.set_xticks([])
ax.set_yticks([])

ax = fig.add_subplot(222)
ax.pcolor(x, y, u, cmap='coolwarm')
ax.set_xticks([])
ax.set_yticks([])

plt.savefig('adv_plot3new.eps', format='eps', bbox_inches='tight')

plt.show()

# %%
# Define parameters
L = 10
x = np.linspace(-L, L, 100)
y = x
X, Y = np.meshgrid(x, y)
m = 1  # number of spirals
u = np.tanh(np.sqrt(X**2 + Y**2)) * np.cos(m * np.angle(X + 1j * Y) - np.sqrt(X**2 + Y**2))

fig = plt.figure()
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(221, projection='3d')
ax.plot_surface(X, Y, u, color='red')
plt.gca().set_xticks([])
plt.gca().set_yticks([])
plt.gca().set_zticks([])

ax = fig.add_subplot(222, projection='3d')
ax.plot_surface(X, Y, u, cmap='hot')
plt.gca().set_xticks([])
plt.gca().set_yticks([])
plt.gca().set_zticks([])

ax = fig.add_subplot(223, projection='3d')
ax.plot_surface(X, Y, u, cmap='gray')
plt.gca().set_xticks([])
plt.gca().set_yticks([])
plt.gca().set_zticks([])

ax = fig.add_subplot(224, projection='3d')
ax.plot_surface(X, Y, u, color='gray')
plt.gca().set_xticks([])
plt.gca().set_yticks([])
plt.gca().set_zticks([])

plt.savefig('adv_plot3v2new.eps', format='eps', bbox_inches='tight')

plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
x = np.linspace(-10, 10, 100)
t = np.linspace(0, 10, 50)
X, T = np.meshgrid(x, t)
f = np.cosh(X)**(-1) * (1 - 0.5 * np.cos(2 * T))
+ (np.cosh(X)**(-1) * np.tanh(X)) * (1 - 0.5 * np.sin(2 * T))

fig = plt.figure()
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(221, projection='3d')
ax.plot_wireframe(X, T, f, color='k', rstride=5, cstride=0)
ax.set_xlabel('X'); ax.set_ylabel('T'); ax.set_zlabel('f')
ax.view_init(elev=30, azim=55)


ax = fig.add_subplot(222, projection='3d')
surf = ax.plot_surface(X, T, f, color='gray', antialiased=False)
ax.set_xlabel('X'); ax.set_ylabel('T'); ax.set_zlabel('f')
ax.view_init(elev=30, azim=55)

plt.savefig('adv_plot4v2new.eps', format='eps', bbox_inches='tight')

plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## 7.2 - Mais 2D e 3D

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

L = 10
x = np.linspace(-L, L, 50)
y = x
X, Y = np.meshgrid(x, y)

m = 1  # number of spirals
u = np.tanh(np.sqrt(X**2 + Y**2)) * np.cos(m * np.angle(X
                            + 1j * Y) - np.sqrt(X**2 + Y**2))

# Plot subplot 1
fig = plt.figure()
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(221, projection='3d')
ax.plot_surface(X, Y, u + 2, color='gray')
ax.contour(X, Y, u, zdir='u', offset=np.min(u), cmap='gray', linestyles='solid')

plt.xlabel(r'$x, \xi$', fontsize=15, fontweight='bold')
plt.ylabel(r'$y, \zeta$', fontsize=15, fontweight='bold')
plt.xticks([-L, -7.5, -5, -2.5, 0, 2.5, 5, 7.5, L], ['-L', ' ', ' ', ' ', '0', ' ', ' ', ' ', 'L'], fontsize=15)
plt.yticks([-L, -7.5, -5, -2.5, 0, 2.5, 5, 7.5, L], ['-L', ' ', ' ', ' ', '0', ' ', ' ', ' ', 'L'], fontsize=15)
ax.set_zticks([0, 1, 2, 3])
ax.set_zticklabels(['', '-1', '0', '1'], fontsize=15)
ax.view_init(elev=30, azim=55)

ax = fig.add_subplot(222, projection='3d')
ax.plot_surface(X, Y, u + 2, color='gray', alpha=0.7)
ax.contour(X, Y, u, zdir='u', offset=np.min(u), cmap='gray', linestyles='solid')

plt.xlabel(r'$x, \xi$', fontsize=15, fontweight='bold')
plt.ylabel(r'$y, \zeta$', fontsize=15, fontweight='bold')
plt.xticks([-L, -7.5, -5, -2.5, 0, 2.5, 5, 7.5, L], ['-L', ' ', ' ', ' ', '0', ' ', ' ', ' ', 'L'], fontsize=15)
plt.yticks([-L, -7.5, -5, -2.5, 0, 2.5, 5, 7.5, L], ['-L', ' ', ' ', ' ', '0', ' ', ' ', ' ', 'L'], fontsize=15)
ax.set_zticks([0, 1, 2, 3])
ax.set_zticklabels(['', '-1', '0', '1'], fontsize=15)
ax.view_init(elev=30, azim=55)

plt.tight_layout()

plt.savefig('adv_plot13new.eps', format='eps', bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-12-f4415cc87c2a>:42: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import numpy as np
import scipy.interpolate
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Plot slices of the data at the given coordinates
def plot_slices(x, y, z, data, xslice, yslice, zslice, ax=None):
    if ax is None:
        ax = plt.figure().add_subplot(111, projection='3d')
    # Normalize data to [0, 1] range
    vmin, vmax = data.min(), data.max()
    data_n = (data - vmin) / (vmax - vmin)
    # Take slices interpolating to allow for arbitrary values
    data_x = scipy.interpolate.interp1d(x, data, axis=0)(xslice)
    data_y = scipy.interpolate.interp1d(y, data, axis=1)(yslice)
    data_z = scipy.interpolate.interp1d(z, data, axis=2)(zslice)
    # Pick color map
    cmap = plt.cm.plasma
    # Plot X slice
    xs, ys, zs = data.shape
    xplot = ax.plot_surface(xslice, y[:, np.newaxis], z[np.newaxis, :],
                            rstride=1, cstride=1, facecolors=cmap(data_x), shade=False)
    # Plot Y slice
    yplot = ax.plot_surface(x[:, np.newaxis], yslice, z[np.newaxis, :],
                            rstride=1, cstride=1, facecolors=cmap(data_y), shade=False)
    # Plot Z slice
    zplot = ax.plot_surface(x[:, np.newaxis], y[np.newaxis, :], np.atleast_2d(zslice),
                            rstride=1, cstride=1, facecolors=cmap(data_z), shade=False)
    return xplot, yplot, zplot


x = np.linspace(-3, 3, 20)
y = x
z = x
X, Y, Z = np.meshgrid(x, y, z)
u = np.cos(X) * np.cos(Y) * np.cos(Z)

ax = plt.figure().add_subplot(111, projection='3d')
plot_slices(x, y, z, u, -3, 3, 0, ax=ax)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.5, 0, 'Z')

# %% [markdown]
# ## 7.3 - Animacao

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from PIL import Image

L = 10; x = np.linspace(-L, L, 50); y = x
X, Y = np.meshgrid(x, y)

nt=30; frames = []
for j in range(nt):
    u = np.tanh(np.sqrt(X**2 + Y**2)) * np.cos((np.angle(X + 1j * Y)
                                    - np.sqrt(X**2 + Y**2)) + j)

    fig = plt.figure(figsize=(15, 10))
    plt.imshow(u, cmap='coolwarm')
    plt.title(f'Frame {j + 1}/{nt}')
    plt.savefig(f'frame_{j}.png', dpi=80)  # Adjust dpi as needed
    plt.close()
    frame = Image.open(f'frame_{j}.png')
    frames.append(frame)

frames[0].save('animation.gif', save_all=True,
               append_images=frames[1:], loop=0, duration=100)  # Adjust duration as needed

# %%
from IPython.display import Image

Image(filename='animation.gif')  # Adjust duration as needed
